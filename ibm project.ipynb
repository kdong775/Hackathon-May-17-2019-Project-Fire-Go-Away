# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loc_df = pd.read_json('MOCK_DATA2.json')
loc_df
# Out:
#        contact                     location           name  price  spaces  \
# 0   6145038428           511 Lukken Terrace        Twinder  $6.61     158
# 1   2099413463             0112 Green Plaza       Riffwire  $5.83    9723
# 2   9966447644     396 Charing Cross Avenue        Demimbu  $9.66       3
# 3   5597199845               2 Ruskin Drive        Nlounge  $8.22     513
# 4   5455173999             79401 Sage Drive          Lazzy  $5.18      36
# 5   4044153770          976 Maryland Street       Wordtune  $9.48   57824
# 6   7434825301         8964 Cascade Parkway          Oodoo  $8.70   36276
# 7   5334971061           109 Lake View Pass        Dablist  $9.26      20
# 8   2676084798           42240 Stephen Lane          Rooxo  $6.44      31
# 9   8694765270           19731 Dexter Alley         Devbug  $3.56      17
# 10  3832040854         527 Mosinee Crossing       Realbuzz  $5.16   38152
# 11  8395251801             0241 Miller Road       Innotype  $5.99      77
# ...

# %%
loc_df = pd.read_json('MOCK_DATA.json')
loc_df
# Out:
#       contact                                       location  \
# 0  6195038428     9700 N Torrey Pines Rd, La Jolla, CA 92037
# 1   619042628    11480 N Torrey Pines Rd, La Jolla, CA 92037
# 2  6191432428    10950 N Torrey Pines Rd, La Jolla, CA 92037
# 3  6199872428  3777 La Jolla Village Dr, San Diego, CA 92122
# 4  6199872428            3299 Holiday Ct, La Jolla, CA 92037
#
#                             name    price  spaces  \
# 0  Estancia La Jolla Hotel & Spa  $116.61     158
# 1         The Lodge Torrey Pines  $116.61      18
# 2                Hilton La Jolla   $100.9     208
# 3         Hyatt Regency La Jolla   $140.7     208
# 4              Sheraton La Jolla   $140.7     208
#
#                                              website
# 0  https://meritagecollection.com/estancia-la-jol...
# 1                  https://www.lodgetorreypines.com/
# 2  https://www3.hilton.com/en/hotels/california/h...
# 3  https://www.hyatt.com/en-US/hotel/california/h...
# ...
